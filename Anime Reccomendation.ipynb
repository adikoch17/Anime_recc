# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing data files
# Data from https://www.kaggle.com/yonatanrabinovich/anime-recommendations-project/data

# %%
anime_df = pd.read_csv("anime.csv")

# %%
anime_df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
rating_df = pd.read_csv("rating.csv")

# %%
rating_df.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 178.8 MB

# %% [markdown]
# #### Missing values in Anime_df

# %%
print(round(anime_df.isnull().sum().sort_values(ascending=False)/len(anime_df.index),4)*100)
# Out:
# rating      1.87
# genre       0.50
# type        0.20
# anime_id    0.00
# name        0.00
# episodes    0.00
# members     0.00
# dtype: float64

# %% [markdown]
# #### Missing values in Rating_df

# %%
print(round(rating_df.isnull().sum().sort_values(ascending=False)/len(rating_df.index),4)*100)
# Out:
# user_id     0.0
# anime_id    0.0
# rating      0.0
# dtype: float64

# %% [markdown]
# #### dropping anime with no rating

# %%
anime_df = anime_df[~anime_df["rating"].isnull()]

# %%
print(round(anime_df.isnull().sum().sort_values(ascending=False)/len(anime_df.index),4)*100)
# Out:
# genre       0.39
# anime_id    0.00
# name        0.00
# type        0.00
# episodes    0.00
# rating      0.00
# members     0.00
# dtype: float64

# %% [markdown]
# #### Filling in na values

# %%
anime_df['genre'] = anime_df['genre'].fillna(anime_df['genre'].dropna().mode().values[0])

# %%
print(round(anime_df.isnull().sum().sort_values(ascending=False)/len(anime_df.index),4)*100)
# Out:
# anime_id    0.0
# name        0.0
# genre       0.0
# type        0.0
# episodes    0.0
# rating      0.0
# members     0.0
# dtype: float64

# %% [markdown]
# ### Feature engineering

# %%
rating_df['rating'] = rating_df['rating'].apply(lambda x: np.nan if x==-1 else x)
rating_df.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20     NaN
# 1        1        24     NaN
# 2        1        79     NaN
# 3        1       226     NaN
# 4        1       241     NaN

# %% [markdown]
# ### Number of users in the rating dataframe

# %%
len(rating_df["user_id"].unique())
# Out:
# 73515

# %% [markdown]
# ### Making a new dataframe to perform cosine similarity

# %%
rated_anime = rating_df.merge(anime_df, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])

# %%
rated_anime.head()
# Out:
#    user_id  anime_id  rating_user    name  \
# 0        1        20          NaN  Naruto
# 1        3        20          8.0  Naruto
# 2        5        20          6.0  Naruto
# 3        6        20          NaN  Naruto
# 4       10        20          NaN  Naruto
#
#                                                genre type episodes  rating  \
# 0  Action, Comedy, Martial Arts, Shounen, Super P...   TV      220    7.81
# 1  Action, Comedy, Martial Arts, Shounen, Super P...   TV      220    7.81
# 2  Action, Comedy, Martial Arts, Shounen, Super P...   TV      220    7.81
# 3  Action, Comedy, Martial Arts, Shounen, Super P...   TV      220    7.81
# 4  Action, Comedy, Martial Arts, Shounen, Super P...   TV      220    7.81
#
#    members
# 0   683297
# 1   683297
# 2   683297
# 3   683297
# 4   683297

# %% [markdown]
# #### we only require to user_id, name and rating

# %%
rated_anime = rated_anime[["user_id","name","rating"]]

# %%
rated_anime = rated_anime[rated_anime["user_id"]<=8000]

# %%
rated_anime.head()
# Out:
#    user_id    name  rating
# 0        1  Naruto    7.81
# 1        3  Naruto    7.81
# 2        5  Naruto    7.81
# 3        6  Naruto    7.81
# 4       10  Naruto    7.81

# %% [markdown]
# #### now we pivot the table with users as index and animes as columns

# %%
pivot = rated_anime.pivot_table(index="user_id",columns="name",values="rating")

# %%
pivot.head()
# Out:
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# 5                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
# 5                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 2                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 4                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum  ...  \
# user_id                                     ...
# 1                      NaN             NaN  ...
# 2                      NaN             NaN  ...
# 3                      NaN             NaN  ...
# 4                      NaN             NaN  ...
# 5                      NaN             NaN  ...
#
# name     gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# user_id
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
#
# name     iDOLM@STER Xenoglossia  iDOLM@STER Xenoglossia Specials  s.CRY.ed  \
# user_id
# 1                           NaN                              NaN       NaN
# 2                           NaN                              NaN       NaN
# 3                           NaN                              NaN       NaN
# 4                           NaN                              NaN       NaN
# 5                           NaN                              NaN       NaN
#
# name     xxxHOLiC  xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# user_id
# 1             NaN           NaN                                      NaN
# 2             NaN           NaN                                      NaN
# 3             NaN           NaN                                      NaN
# 4             NaN           NaN                                      NaN
# 5            8.11           NaN                                      NaN
#
# name     xxxHOLiC Rou  xxxHOLiC Shunmuki   ◯
# user_id
# 1                 NaN                NaN NaN
# 2                 NaN                NaN NaN
# 3                 NaN                NaN NaN
# 4                 NaN                NaN NaN
# 5                 NaN                NaN NaN
#
# [5 rows x 8203 columns]

# %% [markdown]
# ***

# %% [markdown]
# ### engineering the pivot table

# %% [markdown]
# #### replacing NaN values with 0

# %%
pivot = pivot.fillna(0)

# %% [markdown]
# #### removing anime with no ratings

# %%
pivot = pivot.T

# %%
pivot.head()
# Out:
# user_id                                             1     2     3     4     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0   0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0   0.0   0.0
#
# user_id                                             5     6     7     8     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0   0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0   0.0   0.0
#
# user_id                                             9     10    ...  7991  \
# name                                                            ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0  ...   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0  ...   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0  ...   0.0
# .hack//G.U. Returner                                 0.0   0.0  ...   0.0
# .hack//G.U. Trilogy                                  0.0   0.0  ...   0.0
#
# user_id                                             7992  7993  7994  7995  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0   0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0   0.0   0.0
#
# user_id                                             7996  7997  7998  7999  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0   0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0   0.0   0.0
#
# user_id                                             8000
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0
# .hack//G.U. Returner                                 0.0
# .hack//G.U. Trilogy                                  0.0
#
# [5 rows x 8000 columns]

# %%
pivot = pivot.loc[:,(pivot != 0).any(axis=0)]

# %% [markdown]
# ### Fitting to similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
import scipy as sp

# %%
piv_sparse = sp.sparse.csr_matrix(pivot.values)

# %%
anime_similarity = cosine_similarity(piv_sparse)

#Df of anime similarities
ani_sim_df = pd.DataFrame(anime_similarity, index = pivot.index, columns = pivot.index)

# %%
ani_sim_df.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.648924
# &quot;Bungaku Shoujo&quot; Movie                                                             0.585662
# .hack//G.U. Returner                                                                         0.101093
# .hack//G.U. Trilogy                                                                          0.072894
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.648924
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.599520
# .hack//G.U. Returner                                                          0.123877
# .hack//G.U. Trilogy                                                           0.099248
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.585662
# &quot;Bungaku Shoujo&quot; Memoire                                          0.599520
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                        0.131854
# .hack//G.U. Trilogy                                                         0.112241
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...              0.101093
# &quot;Bungaku Shoujo&quot; Memoire                              0.123877
# &quot;Bungaku Shoujo&quot; Movie                                0.131854
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.666246
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.072894
# &quot;Bungaku Shoujo&quot; Memoire                             0.099248
# &quot;Bungaku Shoujo&quot; Movie                               0.112241
# .hack//G.U. Returner                                           0.666246
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//G.U. Trilogy: Parody Mode  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.063112
# &quot;Bungaku Shoujo&quot; Memoire                                          0.070305
# &quot;Bungaku Shoujo&quot; Movie                                            0.090033
# .hack//G.U. Returner                                                        0.558579
# .hack//G.U. Trilogy                                                         0.513336
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...     0.085730
# &quot;Bungaku Shoujo&quot; Memoire                     0.127336
# &quot;Bungaku Shoujo&quot; Movie                       0.124240
# .hack//G.U. Returner                                   0.476088
# .hack//G.U. Trilogy                                    0.445005
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.083794
# &quot;Bungaku Shoujo&quot; Memoire                           0.114089
# &quot;Bungaku Shoujo&quot; Movie                             0.129025
# .hack//G.U. Returner                                         0.436256
# .hack//G.U. Trilogy                                          0.419425
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.056505
# &quot;Bungaku Shoujo&quot; Memoire                           0.089922
# &quot;Bungaku Shoujo&quot; Movie                             0.111864
# .hack//G.U. Returner                                         0.462283
# .hack//G.U. Trilogy                                          0.451181
#
# name                                                .hack//Quantum  ...  \
# name                                                                ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.145795  ...
# &quot;Bungaku Shoujo&quot; Memoire                        0.133753  ...
# &quot;Bungaku Shoujo&quot; Movie                          0.160796  ...
# .hack//G.U. Returner                                      0.357200  ...
# .hack//G.U. Trilogy                                       0.364882  ...
#
# name                                                gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                              0.0
# &quot;Bungaku Shoujo&quot; Memoire                                                              0.0
# &quot;Bungaku Shoujo&quot; Movie                                                                0.0
# .hack//G.U. Returner                                                                            0.0
# .hack//G.U. Trilogy                                                                             0.0
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                0.069673
# &quot;Bungaku Shoujo&quot; Memoire                                0.058211
# &quot;Bungaku Shoujo&quot; Movie                                  0.042597
# .hack//G.U. Returner                                              0.054411
# .hack//G.U. Trilogy                                               0.058124
#
# name                                                iDOLM@STER Xenoglossia Specials  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         0.040226
# &quot;Bungaku Shoujo&quot; Memoire                                         0.044811
# &quot;Bungaku Shoujo&quot; Movie                                           0.032791
# .hack//G.U. Returner                                                       0.041885
# .hack//G.U. Trilogy                                                        0.033558
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.028587  0.185795
# &quot;Bungaku Shoujo&quot; Memoire                  0.038215  0.155230
# &quot;Bungaku Shoujo&quot; Movie                    0.051268  0.160923
# .hack//G.U. Returner                                0.101207  0.124943
# .hack//G.U. Trilogy                                 0.152630  0.142080
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.194593
# &quot;Bungaku Shoujo&quot; Memoire                      0.163902
# &quot;Bungaku Shoujo&quot; Movie                        0.166366
# .hack//G.U. Returner                                    0.123549
# .hack//G.U. Trilogy                                     0.130661
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.193696
# &quot;Bungaku Shoujo&quot; Memoire                                                 0.166454
# &quot;Bungaku Shoujo&quot; Movie                                                   0.153385
# .hack//G.U. Returner                                                               0.115249
# .hack//G.U. Trilogy                                                                0.110803
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.252794
# &quot;Bungaku Shoujo&quot; Memoire                      0.227104
# &quot;Bungaku Shoujo&quot; Movie                        0.212720
# .hack//G.U. Returner                                    0.067928
# .hack//G.U. Trilogy                                     0.081635
#
# name                                                xxxHOLiC Shunmuki    ◯
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.236317  0.0
# &quot;Bungaku Shoujo&quot; Memoire                           0.184989  0.0
# &quot;Bungaku Shoujo&quot; Movie                             0.171814  0.0
# .hack//G.U. Returner                                         0.113057  0.0
# .hack//G.U. Trilogy                                          0.106564  0.0
#
# [5 rows x 8203 columns]

# %%
ani_sim_df["Naruto"].sort_values(ascending=False)
# Out:
# name
# Naruto                                1.000000
# Death Note                            0.607310
# Fullmetal Alchemist                   0.548035
# Code Geass: Hangyaku no Lelouch       0.540799
# Code Geass: Hangyaku no Lelouch R2    0.520423
#                                         ...
# Hermes: Ai wa Kaze no Gotoku          0.000000
# Hey! Bumboo                           0.000000
# Hi no Tori: Uchuu-hen                 0.000000
# Hibari no Yadogae                     0.000000
# Hana to Mogura                        0.000000
# Name: Naruto, Length: 8203, dtype: float64

# %%
def anime_recc():
#     while True:
    ani_name = input("What anime do you like? ")
    number = 1
    print('Recommended because you watched {}:\n'.format(ani_name))
    for anime in ani_sim_df.sort_values(by = ani_name, ascending = False).index[1:6]:
        print(f'#{number}: {anime}, {round(ani_sim_df[anime][ani_name]*100,2)}% match')
        number +=1

# %%
anime_recc()
# Out:
# What anime do you like? Dragon Ball Z
# Recommended because you watched Dragon Ball Z:
#
# #1: Dragon Ball, 80.53% match
# #2: Dragon Ball GT, 77.45% match
# #3: Naruto, 51.97% match
# #4: Death Note, 49.48% match
# #5: Fullmetal Alchemist, 47.95% match
